# %%
import pandas as pd
df_listed = pd.read_csv("data/CRMLSListing202602.csv")
df_sold = pd.read_csv("data/CRMLSSold202602.csv")

# %%
df_listed.head(20)
# Out:
#     OriginalListPrice  ListingKey   CloseDate  ClosePrice ListAgentFirstName  \
# 0            599000.0  1155878924         NaN         NaN             Rhonda
# 1            699000.0  1155878603         NaN         NaN            Frances
# 2           1250000.0  1155878531  2026-03-24   1250000.0             Marcel
# 3             27000.0  1155877325         NaN         NaN            Georgie
# 4            699000.0  1155873898         NaN         NaN               Ryan
# 5           2899000.0  1155873726         NaN         NaN                Rob
# 6            399000.0  1155871031         NaN         NaN            Annette
# 7           1349000.0  1155870845         NaN         NaN             Lauren
# 8            750000.0  1155868238         NaN         NaN              Jimmy
# 9           1200000.0  1155868139         NaN         NaN            Nasheen
# 10          1998000.0  1155866218         NaN         NaN             Debbie
# ...

# %% [markdown]
# Pricing:
#     Original List Price
#     Close Price
# Dates:
#     Close Dates
# Location:
#     Latitude, Longitude
#     Postal Code
#     Unparsed Address
#     High School District
# Property Info:
#     Type
#     Garage Spaces
#     Main Level Bedrooms
#     Lost Size

# %%
df_listed.info()
df_listed.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10988 entries, 0 to 10987
# Data columns (total 81 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   OriginalListPrice             10937 non-null  float64
#  1   ListingKey                    10988 non-null  int64
#  2   CloseDate                     1573 non-null   object
#  3   ClosePrice                    1199 non-null   float64
#  4   ListAgentFirstName            10930 non-null  object
#  5   ListAgentLastName             10987 non-null  object
#  6   Latitude                      10844 non-null  float64
#  7   Longitude                     10848 non-null  float64
#  8   UnparsedAddress               10959 non-null  object
#  9   PropertyType                  10988 non-null  object
#  10  LivingArea                    9556 non-null   float64
#  11  ListPrice                     10958 non-null  float64
# ...

# %%
df_sold.head(20)
# Out:
#                BuyerAgentAOR              ListAgentAOR     Flooring ViewYN  \
# 0                ContraCosta                   BayEast          NaN    NaN
# 1               OrangeCounty              OrangeCounty  Carpet,Tile  False
# 2      BeverlyHillsGreaterLa     BeverlyHillsGreaterLa         Wood  False
# 3                   SanDiego                  SanDiego          NaN    NaN
# 4                    Newport                   Newport          NaN  False
# 5                      Mrmls         SierraNorthValley          NaN   True
# 6               CitrusValley      WestSanGabrielValley          NaN  False
# 7                    BayEast                   Oakland       Carpet    NaN
# 8                    Newport                   Newport    Tile,Wood   True
# 9                Mlslistings               Mlslistings          NaN  False
# 10       NorthSanDiegoCounty       NorthSanDiegoCounty     Laminate  False
# ...

# %%
df_sold.info()
df_sold.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19069 entries, 0 to 19068
# Data columns (total 79 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   BuyerAgentAOR                 17550 non-null  object
#  1   ListAgentAOR                  19064 non-null  object
#  2   Flooring                      10943 non-null  object
#  3   ViewYN                        17234 non-null  object
#  4   WaterfrontYN                  17 non-null     object
#  5   BasementYN                    294 non-null    object
#  6   PoolPrivateYN                 16978 non-null  object
#  7   OriginalListPrice             19005 non-null  float64
#  8   ListingKey                    19069 non-null  int64
#  9   CloseDate                     19069 non-null  object
#  10  ClosePrice                    19067 non-null  float64
#  11  ListAgentFirstName            19008 non-null  object
# ...
